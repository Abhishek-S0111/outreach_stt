# %% [markdown]
# # 🎙️ Pipeline Fallback Step: RNNoise Noise Suppression
#
# Uses Mozilla's real-time recurrent neural network for noise suppression (RNNoise) to filter speech frequencies.
#
# ## Environment Setup

# %%
# %%capture
# !pip install rnnoise-wrapper
from rnnoise_wrapper import RNNoise
import os

# %% [markdown]
# ## Google Drive Mount & Form Configuration

# %%
try:
    drive.mount('/content/drive')
    print("Google Drive successfully mounted.")
except Exception as e:
    print(f"Drive mount error: {e}")

# @markdown ### 📂 Separation Configuration
input_audio_path = "/content/drive/MyDrive/annam AI tasks/outreach activity/transcription result/backup fallback strategies/MarauliKhurad3/standardized.wav" # @param {type:"string"}
output_audio_path = "/content/drive/MyDrive/annam AI tasks/outreach activity/transcription result/backup fallback strategies/MarauliKhurad3/cleaned_audio.wav" # @param {type:"string"}

os.makedirs(os.path.dirname(output_audio_path), exist_ok=True)

# %% [markdown]
# ## Execute Fallback Processing

# %%
try:
    print("Loading RNNoise engine...")
    denoiser = RNNoise()
    
    print(f"Denoising audio file: {input_audio_path}")
    denoiser.denoise_file(input_audio_path, output_audio_path)
    print(f"\n[SUCCESS] RNNoise output saved to: {output_audio_path}")
except Exception as e:
    print(f"\n[ERROR] RNNoise processing failed: {e}")
