# %% [markdown]
# # 🎙️ Pipeline Fallback Step: DeepFilterNet Noise Suppression
#
# Applies deep filtering using DeepFilterNet to remove non-stationary transient background noise and reverberation.
#
# ## Environment Setup

# %%
# %%capture
# !pip install dfnet
import os
from df import enhance, init_df

# %% [markdown]
# ## Google Drive Mount & Form Configuration

# %%
try:
    drive.mount('/content/drive')
    print("Google Drive successfully mounted.")
except Exception as e:
    print(f"Drive mount error: {e}")

# @markdown ### 📂 Separation Configuration
input_audio_path = "/content/drive/MyDrive/annam AI tasks/outreach activity/transcription result/backup fallback strategies/MarauliKhurad3/standardized.wav" # @param {type:"string"}
output_audio_path = "/content/drive/MyDrive/annam AI tasks/outreach activity/transcription result/backup fallback strategies/MarauliKhurad3/cleaned_audio.wav" # @param {type:"string"}

os.makedirs(os.path.dirname(output_audio_path), exist_ok=True)

# %% [markdown]
# ## Execute Fallback Processing

# %%
try:
    print("Initializing DeepFilterNet model...")
    model, df_state = init_df()
    
    print(f"Enhancing audio file: {input_audio_path}")
    # Enhance audio
    enhanced_audio = enhance(model, df_state, input_audio_path)
    
    # Save enhanced audio
    import soundfile as sf
    sf.write(output_audio_path, enhanced_audio, 16000, format='WAV', subtype='PCM_16')
    print(f"\n[SUCCESS] DeepFilterNet enhanced audio saved to: {output_audio_path}")
except Exception as e:
    print(f"\n[ERROR] DeepFilterNet enhancement failed: {e}")
